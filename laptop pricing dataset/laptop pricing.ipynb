# %%
import pandas as pd
import numpy as np

df=pd.read_csv("C:/Users/VIVEK/OneDrive/Desktop/DATA Sci. Material/dataset cleaning/laptopData.csv")
df.tail()
# Out:
#       Unnamed: 0 Company            TypeName Inches  \
# 1298      1298.0  Lenovo  2 in 1 Convertible     14
# 1299      1299.0  Lenovo  2 in 1 Convertible   13.3
# 1300      1300.0  Lenovo            Notebook     14
# 1301      1301.0      HP            Notebook   15.6
# 1302      1302.0    Asus            Notebook   15.6
#
#                                 ScreenResolution  \
# 1298   IPS Panel Full HD / Touchscreen 1920x1080
# 1299  IPS Panel Quad HD+ / Touchscreen 3200x1800
# 1300                                    1366x768
# 1301                                    1366x768
# 1302                                    1366x768
#
#                                        Cpu   Ram              Memory  \
# 1298            Intel Core i7 6500U 2.5GHz   4GB           128GB SSD
# 1299            Intel Core i7 6500U 2.5GHz  16GB           512GB SSD
# 1300  Intel Celeron Dual Core N3050 1.6GHz   2GB  64GB Flash Storage
# 1301            Intel Core i7 6500U 2.5GHz   6GB             1TB HDD
# ...

# %%
df.columns
df.shape
df
# Out:
#       Unnamed: 0 Company            TypeName Inches  \
# 0            0.0   Apple           Ultrabook   13.3
# 1            1.0   Apple           Ultrabook   13.3
# 2            2.0      HP            Notebook   15.6
# 3            3.0   Apple           Ultrabook   15.4
# 4            4.0   Apple           Ultrabook   13.3
# ...          ...     ...                 ...    ...
# 1298      1298.0  Lenovo  2 in 1 Convertible     14
# 1299      1299.0  Lenovo  2 in 1 Convertible   13.3
# 1300      1300.0  Lenovo            Notebook     14
# 1301      1301.0      HP            Notebook   15.6
# 1302      1302.0    Asus            Notebook   15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...

# %%
#Checking and dropping the duplicate values.
df.duplicated()
df=df.drop_duplicates()

# %%
df.drop(columns=['Unnamed: 0'],inplace=True)
df.isnull().sum()
# Out:
# C:\Users\VIVEK\AppData\Local\Temp\ipykernel_12632\1371157125.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(columns=['Unnamed: 0'],inplace=True)
# Company             1
# TypeName            1
# Inches              1
# ScreenResolution    1
# Cpu                 1
# Ram                 1
# Memory              1
# Gpu                 1
# OpSys               1
# Weight              1
# Price               1
# dtype: int64

# %%
df['Inches'].unique()
# Out:
# array(['13.3', '15.6', '15.4', '14', '12', nan, '17.3', '13.5', '12.5',
#        '13', '18.4', '13.9', '11.6', '25.6', '35.6', '12.3', '27.3', '24',
#        '33.5', '?', '31.6', '17', '15', '14.1', '11.3', '10.1'],
#       dtype=object)

# %%
df['Inches']=df['Inches'].replace('?',np.nan)


#changing the data type of inches column from object to float
df['Inches']=df['Inches'].astype(float)
df['Inches'].fillna
df['Inches'].unique()
# Out:
# C:\Users\VIVEK\AppData\Local\Temp\ipykernel_12632\3119428142.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Inches']=df['Inches'].replace('?',np.nan)
# C:\Users\VIVEK\AppData\Local\Temp\ipykernel_12632\3119428142.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Inches']=df['Inches'].astype(float)
# array([13.3, 15.6, 15.4, 14. , 12. ,  nan, 17.3, 13.5, 12.5, 13. , 18.4,
#        13.9, 11.6, 25.6, 35.6, 12.3, 27.3, 24. , 33.5, 31.6, 17. , 15. ,
#        14.1, 11.3, 10.1])

# %%
df['Inches']=df['Inches'].fillna(df['Inches'].mean())
# Out:
# C:\Users\VIVEK\AppData\Local\Temp\ipykernel_12632\1970866030.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Inches']=df['Inches'].fillna(df['Inches'].mean())

# %%
df['ScreenResolution'].value_counts()
# Out:
# Full HD 1920x1080                                495
# 1366x768                                         274
# IPS Panel Full HD 1920x1080                      226
# IPS Panel Full HD / Touchscreen 1920x1080         52
# Full HD / Touchscreen 1920x1080                   45
# 1600x900                                          23
# Touchscreen 1366x768                              16
# Quad HD+ / Touchscreen 3200x1800                  14
# IPS Panel 4K Ultra HD 3840x2160                   12
# IPS Panel 4K Ultra HD / Touchscreen 3840x2160     11
# 4K Ultra HD / Touchscreen 3840x2160                9
# 4K Ultra HD 3840x2160                              7
# IPS Panel 1366x768                                 7
# IPS Panel Retina Display 2560x1600                 6
# IPS Panel Quad HD+ / Touchscreen 3200x1800         6
# Touchscreen 2560x1440                              6
# IPS Panel Retina Display 2304x1440                 6
# Touchscreen 2256x1504                              6
# ...

# %%
df['resolution']=df['ScreenResolution'].str.extract("(\d+x\d+)")
df['resolution']
# Out:
# C:\Users\VIVEK\AppData\Local\Temp\ipykernel_12632\1970960976.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['resolution']=df['ScreenResolution'].str.extract("(\d+x\d+)")
# 0       2560x1600
# 1        1440x900
# 2       1920x1080
# 3       2880x1800
# 4       2560x1600
#           ...
# 1298    1920x1080
# 1299    3200x1800
# 1300     1366x768
# 1301     1366x768
# 1302     1366x768
# Name: resolution, Length: 1274, dtype: object

# %%
df['ScreenResolution']=df['resolution']
df.rename(columns={'ScreenResolution':'Resolution'},inplace=True)
# Out:
# C:\Users\VIVEK\AppData\Local\Temp\ipykernel_12632\1784067709.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['ScreenResolution']=df['resolution']
# C:\Users\VIVEK\AppData\Local\Temp\ipykernel_12632\1784067709.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.rename(columns={'ScreenResolution':'Resolution'},inplace=True)

# %%
#df['Memory'].value_counts

# %%
df['Memory']=df['Memory'].replace('?',np.nan)
# Out:
# C:\Users\VIVEK\AppData\Local\Temp\ipykernel_12632\3999618163.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Memory']=df['Memory'].replace('?',np.nan)

# %%
df[['Memory', 'M_type']] = df['Memory'].str.split(' ', 1, expand=True)
# Out:
# C:\Users\VIVEK\AppData\Local\Temp\ipykernel_12632\669108800.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[['Memory', 'M_type']] = df['Memory'].str.split(' ', 1, expand=True)
# C:\Users\VIVEK\AppData\Local\Temp\ipykernel_12632\669108800.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[['Memory', 'M_type']] = df['Memory'].str.split(' ', 1, expand=True)

# %%
df
# Out:
#      Company            TypeName  Inches Resolution  \
# 0      Apple           Ultrabook    13.3  2560x1600
# 1      Apple           Ultrabook    13.3   1440x900
# 2         HP            Notebook    15.6  1920x1080
# 3      Apple           Ultrabook    15.4  2880x1800
# 4      Apple           Ultrabook    13.3  2560x1600
# ...      ...                 ...     ...        ...
# 1298  Lenovo  2 in 1 Convertible    14.0  1920x1080
# 1299  Lenovo  2 in 1 Convertible    13.3  3200x1800
# 1300  Lenovo            Notebook    14.0   1366x768
# 1301      HP            Notebook    15.6   1366x768
# 1302    Asus            Notebook    15.6   1366x768
#
#                                        Cpu   Ram Memory  \
# 0                     Intel Core i5 2.3GHz   8GB  128GB
# 1                     Intel Core i5 1.8GHz   8GB  128GB
# 2               Intel Core i5 7200U 2.5GHz   8GB  256GB
# 3                     Intel Core i7 2.7GHz  16GB  512GB
# ...

# %%
nvalue=df[df.isnull().any(axis=1)]
nvalue
# Out:
#     Company  TypeName  Inches Resolution                         Cpu   Ram  \
# 770    Dell  Notebook    15.6  1920x1080  Intel Core i7 7500U 2.7GHz  16GB
#
#     Memory                 Gpu       OpSys Weight       Price resolution  \
# 770    NaN  AMD Radeon R7 M445  Windows 10  2.3kg  62938.0656  1920x1080
#
#     M_type
# 770    NaN

# %%
df=df.drop(20)
df.reset_index(drop=True)
# Out:
#      Company            TypeName  Inches Resolution  \
# 0      Apple           Ultrabook    13.3  2560x1600
# 1      Apple           Ultrabook    13.3   1440x900
# 2         HP            Notebook    15.6  1920x1080
# 3      Apple           Ultrabook    15.4  2880x1800
# 4      Apple           Ultrabook    13.3  2560x1600
# ...      ...                 ...     ...        ...
# 1268  Lenovo  2 in 1 Convertible    14.0  1920x1080
# 1269  Lenovo  2 in 1 Convertible    13.3  3200x1800
# 1270  Lenovo            Notebook    14.0   1366x768
# 1271      HP            Notebook    15.6   1366x768
# 1272    Asus            Notebook    15.6   1366x768
#
#                                        Cpu   Ram Memory  \
# 0                     Intel Core i5 2.3GHz   8GB  128GB
# 1                     Intel Core i5 1.8GHz   8GB  128GB
# 2               Intel Core i5 7200U 2.5GHz   8GB  256GB
# 3                     Intel Core i7 2.7GHz  16GB  512GB
# ...

# %%
df=df.fillna(' ')

# %%
df.loc[770]
# Out:
# Company                             Dell
# TypeName                        Notebook
# Inches                              15.6
# Resolution                     1920x1080
# Cpu           Intel Core i7 7500U 2.7GHz
# Ram                                 16GB
# Memory
# Gpu                   AMD Radeon R7 M445
# OpSys                         Windows 10
# Weight                             2.3kg
# Price                         62938.0656
# resolution                     1920x1080
# M_type
# Name: 770, dtype: object
